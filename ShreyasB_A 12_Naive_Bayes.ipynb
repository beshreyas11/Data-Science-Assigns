# %% [markdown]
# DS AssignmentDS Assignment 12
#
# Naive Bayes
#
# Train & Test dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/SalaryData_Train.csv")

# %%
data
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
data.shape
# Out:
# (30161, 14)

# %%
data.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
data.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
d1=data[data.duplicated()]

# %%
d1
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 30110   47   Private        HS-grad            9   Married-civ-spouse
# 30118   20   Private        HS-grad            9        Never-married
# 30132   22   Private   Some-college           10        Never-married
# 30157   40   Private        HS-grad            9   Married-civ-spouse
# 30159   22   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
d1=data.drop_duplicates()

# %%
d1
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 30154   53            Private        Masters           14
# 30155   22            Private   Some-college           10
# 30156   27            Private     Assoc-acdm           12
# 30158   58            Private        HS-grad            9
# 30160   52       Self-emp-inc        HS-grad            9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
corr=d1.corr()
# Out:
# <ipython-input-14-7af7e32dfabb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=d1.corr()

# %%
corr
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.038048     0.077235     0.052684      0.072529
# educationno   0.038048     1.000000     0.126085     0.080025      0.145491
# capitalgain   0.077235     0.126085     1.000000    -0.036023      0.079403
# capitalloss   0.052684     0.080025    -0.036023     1.000000      0.049093
# hoursperweek  0.072529     0.145491     0.079403     0.049093      1.000000

# %%
dataz=pd.read_csv("/content/SalaryData_Test.csv")

# %%
dataz
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
dataz.shape
# Out:
# (15060, 14)

# %%
dataz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
dataz.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
dataz[dataz.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
dataz.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
dataz[dataz.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
d2=dataz.drop_duplicates()

# %%
d2
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
corr=d2.corr()
# Out:
# <ipython-input-26-769bdb61892e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=d2.corr()

# %%
corr
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.021979     0.076765     0.053172      0.088090
# educationno   0.021979     1.000000     0.132346     0.085651      0.127779
# capitalgain   0.076765     0.132346     1.000000    -0.033929      0.089512
# capitalloss   0.053172     0.085651    -0.033929     1.000000      0.056353
# hoursperweek  0.088090     0.127779     0.089512     0.056353      1.000000

# %%
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data=data,hue="maritalstatus")

# %%
sns.pairplot(data=dataz,hue="sex")

# %%
data['workclass'].value_counts()
# Out:
#  Private             22285
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: workclass, dtype: int64

# %%
data['education'].value_counts()
# Out:
#  HS-grad         9840
#  Some-college    6677
#  Bachelors       5044
#  Masters         1627
#  Assoc-voc       1307
#  11th            1048
#  Assoc-acdm      1008
#  10th             820
#  7th-8th          557
#  Prof-school      542
#  9th              455
#  12th             377
#  Doctorate        375
#  5th-6th          288
#  1st-4th          151
#  Preschool         45
# Name: education, dtype: int64

# %%
data['maritalstatus'].value_counts()
# Out:
#  Married-civ-spouse       14065
#  Never-married             9725
#  Divorced                  4214
#  Separated                  939
#  Widowed                    827
#  Married-spouse-absent      370
#  Married-AF-spouse           21
# Name: maritalstatus, dtype: int64

# %%
data['occupation'].value_counts()
# Out:
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1965
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
 data['occupation'].value_counts()
# Out:
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1965
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
data['occupation'].value_counts()
# Out:
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1965
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
 data['sex'].value_counts()
# Out:
#  Male      20380
#  Female     9781
# Name: sex, dtype: int64

# %%
data['native'].value_counts()
# Out:
#  United-States                 27504
#  Mexico                          610
#  Philippines                     188
#  Germany                         128
#  Puerto-Rico                     109
#  Canada                          107
#  India                           100
#  El-Salvador                     100
#  Cuba                             92
#  England                          86
#  Jamaica                          80
#  South                            71
#  China                            68
#  Italy                            68
#  Dominican-Republic               67
#  Vietnam                          64
#  Guatemala                        63
#  Japan                            59
#  Poland                           56
#  Columbia                         56
#  Iran                             42
#  Taiwan                           42
#  Haiti                            42
#  Portugal                         34
#  Nicaragua                        33
# ...

# %%
data['native'].value_counts()
# Out:
#  United-States                 27504
#  Mexico                          610
#  Philippines                     188
#  Germany                         128
#  Puerto-Rico                     109
#  Canada                          107
#  India                           100
#  El-Salvador                     100
#  Cuba                             92
#  England                          86
#  Jamaica                          80
#  South                            71
#  China                            68
#  Italy                            68
#  Dominican-Republic               67
#  Vietnam                          64
#  Guatemala                        63
#  Japan                            59
#  Poland                           56
#  Columbia                         56
#  Iran                             42
#  Taiwan                           42
#  Haiti                            42
#  Portugal                         34
#  Nicaragua                        33
# ...

# %%
# Ploting Countolot for Categorical data

plt.subplots(figsize=(30,20))
[plt.subplot(4,2,1), sns.countplot(data=data, y='workclass')];

[plt.subplot(4,2,2), sns.countplot(data=data, y='education')];

[plt.subplot(4,2,3), sns.countplot(data=data, y='maritalstatus')];

[plt.subplot(4,2,4), sns.countplot(data=data, y='occupation')];

[plt.subplot(4,2,5), sns.countplot(data=data, y='relationship')];

[plt.subplot(4,2,6), sns.countplot(data=data, y='race')];

[plt.subplot(4,2,7), sns.countplot(data=data, y='sex')];

[plt.subplot(4,2,8), sns.countplot(data=data, y='Salary')];
# Out:
# <ipython-input-40-7728fc8ab854>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   [plt.subplot(4,2,1), sns.countplot(data=data, y='workclass')];

# %%
no_columns = data.select_dtypes(exclude='object').columns.tolist()

plt.figure(figsize=(15,10))
for i,column in enumerate(no_columns,1):
    plt.subplot(2,3,i)
    sns.kdeplot(data[column],color='g',shade=True)
# Out:
# <ipython-input-41-c85b18955aa5>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[column],color='g',shade=True)
# <ipython-input-41-c85b18955aa5>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[column],color='g',shade=True)
# <ipython-input-41-c85b18955aa5>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[column],color='g',shade=True)
# <ipython-input-41-c85b18955aa5>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[column],color='g',shade=True)
# ...

# %% [markdown]
# ### Ploting Boplot for numerical data

# %%
plt.figure(figsize=(12,12))
[plt.subplot(3,2,1), sns.boxplot(x=data["age"])];

[plt.subplot(3,2,2), sns.boxplot(x=data["educationno"])];

[plt.subplot(3,2,3), sns.boxplot(x=data["capitalgain"])];

[plt.subplot(3,2,4), sns.boxplot(x=data["capitalloss"])];

[plt.subplot(3,2,5), sns.boxplot(x=data["hoursperweek"])];

# %% [markdown]
# ### Converting categorical data into Label Encoding data

# %%
convert = {' >50K': 1, ' <=50K': 2}
d1 = d1.replace({'Salary': convert})

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

columns=["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

# %%
for i in columns:
    d1[i]= label_encoder.fit_transform(d1[i])

# %%
d1
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30154   53          2         12           14              2           3
# 30155   22          2         15           10              4          10
# 30156   27          2          7           12              2          12
# 30158   58          2         11            9              6           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %% [markdown]
# # for TEST dataset

# %%
dataz['workclass'].value_counts()
# Out:
#  Private             11021
#  Self-emp-not-inc     1297
#  Local-gov            1033
#  State-gov             667
#  Self-emp-inc          572
#  Federal-gov           463
#  Without-pay             7
# Name: workclass, dtype: int64

# %%
dataz['education'].value_counts()
# Out:
#  HS-grad         4943
#  Some-college    3221
#  Bachelors       2526
#  Masters          887
#  Assoc-voc        652
#  11th             571
#  Assoc-acdm       499
#  10th             403
#  7th-8th          266
#  Prof-school      243
#  9th              221
#  12th             200
#  Doctorate        169
#  5th-6th          161
#  1st-4th           71
#  Preschool         27
# Name: education, dtype: int64

# %%
 dataz['maritalstatus'].value_counts()
# Out:
#  Married-civ-spouse       6990
#  Never-married            4872
#  Divorced                 2083
#  Separated                 472
#  Widowed                   450
#  Married-spouse-absent     182
#  Married-AF-spouse          11
# Name: maritalstatus, dtype: int64

# %%
 dataz['occupation'].value_counts()
# Out:
#  Exec-managerial      1992
#  Craft-repair         1990
#  Prof-specialty       1970
#  Sales                1824
#  Adm-clerical         1819
#  Other-service        1596
#  Machine-op-inspct    1004
#  Transport-moving      744
#  Handlers-cleaners     696
#  Tech-support          508
#  Farming-fishing       491
#  Protective-serv       332
#  Priv-house-serv        89
#  Armed-Forces            5
# Name: occupation, dtype: int64

# %%
 dataz['relationship'].value_counts()
# Out:
#  Husband           6203
#  Not-in-family     3976
#  Own-child         2160
#  Unmarried         1576
#  Wife               685
#  Other-relative     460
# Name: relationship, dtype: int64

# %%
dataz['race'].value_counts()
# Out:
#  White                 12970
#  Black                  1411
#  Asian-Pac-Islander      408
#  Amer-Indian-Eskimo      149
#  Other                   122
# Name: race, dtype: int64

# %%
 dataz['sex'].value_counts()
# Out:
#  Male      10147
#  Female     4913
# Name: sex, dtype: int64

# %%
dataz['occupation'].value_counts()
# Out:
#  Exec-managerial      1992
#  Craft-repair         1990
#  Prof-specialty       1970
#  Sales                1824
#  Adm-clerical         1819
#  Other-service        1596
#  Machine-op-inspct    1004
#  Transport-moving      744
#  Handlers-cleaners     696
#  Tech-support          508
#  Farming-fishing       491
#  Protective-serv       332
#  Priv-house-serv        89
#  Armed-Forces            5
# Name: occupation, dtype: int64

# %%
dataz['native'].value_counts()
# Out:
#  United-States                 13788
#  Mexico                          293
#  Philippines                      95
#  Puerto-Rico                      66
#  Germany                          65
#  Canada                           56
#  El-Salvador                      47
#  India                            47
#  China                            45
#  Cuba                             41
#  England                          33
#  Italy                            32
#  South                            30
#  Dominican-Republic               30
#  Japan                            30
#  Portugal                         28
#  Haiti                            27
#  Columbia                         26
#  Poland                           25
#  Guatemala                        23
#  Jamaica                          23
#  Greece                           20
#  Vietnam                          19
#  Ecuador                          16
#  Nicaragua                        15
# ...

# %%
 dataz['Salary'].value_counts()
# Out:
#  <=50K    11360
#  >50K      3700
# Name: Salary, dtype: int64

# %% [markdown]
# ### Converting categorical data into Label Encoding data

# %%
for i in columns:
    d2[i]= label_encoder.fit_transform(d2[i])
# Out:
# <ipython-input-57-0a5790a72ee9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2[i]= label_encoder.fit_transform(d2[i])
# <ipython-input-57-0a5790a72ee9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d2[i]= label_encoder.fit_transform(d2[i])
# <ipython-input-57-0a5790a72ee9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
d2
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
convert = {' >50K': 1, ' <=50K': 2}
d2 = d2.replace({'Salary': convert})

# %%
d2
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %% [markdown]
# # Appliying Naive Bayes

# %%
x_train = d1.iloc[:,0:13]
y_train = d1.iloc[:,13]
x_test = d2.iloc[:,0:13]
y_test = d2.iloc[:,13]

# %% [markdown]
# ### normal distribution

# %%
from sklearn.naive_bayes import GaussianNB
clsfrgnb = GaussianNB()   # clsfrgnb = claasification with Gussian Naive Bayes

# %%
model1=clsfrgnb.fit(x_train, y_train)

# %%
y_pred_gnb = model1.predict(x_test)

# %%
y_pred_gnb
# Out:
# array([2, 2, 2, ..., 2, 1, 2])

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_pred_gnb)
# Out:
# array([[ 1180,  2330],
#        [  564, 10056]])

# %%
pd.crosstab(y_test.values.flatten(),clsfrgnb)
# Out:
# col_0  GaussianNB()
# row_0
# 1              3510
# 2             10620

# %%
print ("Accuracy",np.mean(y_pred_gnb==y_test.values.flatten())*100)
# Out:
# Accuracy 79.51875442321303

# %% [markdown]
# ### multinomial

# %%
from sklearn.naive_bayes import MultinomialNB
clsfrmnb = MultinomialNB()

# %%
model2=clsfrmnb.fit(x_train, y_train)

# %%
model2
# Out:
# MultinomialNB()

# %%
y_pred_mnb = model2.predict(x_test)

# %%
confusion_matrix(y_test, y_pred_mnb)
# Out:
# array([[  777,  2733],
#        [  469, 10151]])

# %%
pd.crosstab(y_test.values.flatten(),clsfrmnb)
# Out:
# col_0  MultinomialNB()
# row_0
# 1                 3510
# 2                10620

# %%
print ("Accuracy",np.mean(y_pred_mnb==y_test.values.flatten()))
# Out:
# Accuracy 0.7733899504600141

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred_mnb)
# Out:
# 0.7733899504600141

# %% [markdown]
# ### Cross Validation Check

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
seed = 7
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('MNB', MultinomialNB()))

# %%
results = []
names = []
scoring = 'accuracy'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed,shuffle = True)
    cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.796268 (0.006401)
# KNN: 0.824740 (0.010474)
# CART: 0.786901 (0.005832)
# NB: 0.793703 (0.010001)
# MNB: 0.768316 (0.008122)

# %%
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# Here I compare with different algorithms for checking which algorith gives us higher accuracy
#
# After comparing "KNN" gives higher accuracy
# Accuracy of KNN = 0.824777
